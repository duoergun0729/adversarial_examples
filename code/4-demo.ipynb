# %% [markdown]
# Mac下OpenCV安装方式：
#
#     brew install opencv
#     pip install opencv-python

# %%
import cv2
from matplotlib import pyplot as plt 

img=cv2.imread("../picture/pig.jpg")
show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
plt.imshow(show_img) 
plt.show()

# %%
print(img.shape)
# Out:
# (300, 300, 3)

# %%
img=cv2.imread("../picture/pig.jpg")
show_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(show_img,cmap=plt.cm.gray) 
plt.show()

# %%
print(img.shape)
# Out:
# (300, 300)

# %%
img=cv2.imread("../picture/pig.jpg")
show_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, show_img = cv2.threshold(show_img, 220, 255,cv2.THRESH_BINARY)

plt.imshow(show_img,cmap=plt.cm.gray) 
plt.show()

# %%
print(show_img.shape)
# Out:
# (300, 300)

# %%
img=cv2.imread("../picture/pig.jpg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
plt.subplot(221)
plt.imshow(img) 

img_200=cv2.resize(img,(200,200))
plt.subplot(222)
plt.imshow(img_200) 


plt.show() 

print(img.shape)
print(img_200.shape)
# Out:
# (300, 300, 3)
# (200, 200, 3)

# %%
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

rows,cols,_ = img.shape

# 得到变换的矩阵，通过这个矩阵再利用warpAffine来进行变换
# 第一个参数就是旋转中心，元组的形式，这里设置成相片中心
# 第二个参数90，是旋转的角度
# 第三个参数1，表示放缩的系数，1表示保持原图大小
matrix = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)


img2 = cv2.warpAffine(img1,matrix,(cols,rows))

plt.subplot(121)
plt.imshow(img1) 

plt.subplot(122)
plt.imshow(img2) 


plt.show()

# %%
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

rows,cols,_ = img.shape

matrix = cv2.getRotationMatrix2D((cols/2,rows/2),0,0.5)


img2 = cv2.warpAffine(img1,matrix,(cols,rows))

plt.subplot(121)
plt.imshow(img1) 

plt.subplot(122)
plt.imshow(img2) 


plt.show()

# %%
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

rows,cols,_ = img.shape

matrix = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
img2 = cv2.warpAffine(img1,matrix,(cols,rows))

matrix = cv2.getRotationMatrix2D((cols/2,rows/2),180,1)
img3 = cv2.warpAffine(img1,matrix,(cols,rows))

matrix = cv2.getRotationMatrix2D((cols/2,rows/2),270,1)
img4 = cv2.warpAffine(img1,matrix,(cols,rows))


plt.subplot(221)
plt.imshow(img1) 

plt.subplot(222)
plt.imshow(img2) 

plt.subplot(223)
plt.imshow(img3) 

plt.subplot(224)
plt.imshow(img4) 


plt.show()

# %%
import numpy as np
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

rows,cols,_ = img.shape

matrix = np.float32([[1,0,25],[0,1,25]])
img2 = cv2.warpAffine(img1,matrix,(cols,rows))

matrix = np.float32([[1,0,50],[0,1,50]])
img3 = cv2.warpAffine(img1,matrix,(cols,rows))

matrix = np.float32([[1,0,75],[0,1,75]])
img4 = cv2.warpAffine(img1,matrix,(cols,rows))


plt.subplot(221)
plt.imshow(img1) 

plt.subplot(222)
plt.imshow(img2) 

plt.subplot(223)
plt.imshow(img3) 

plt.subplot(224)
plt.imshow(img4) 


plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
rows,cols,_ = img.shape

img2=img1[50:150,200:300]

plt.subplot(121)
plt.imshow(img1) 

plt.subplot(122)
plt.imshow(img2)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
rows,cols,_ = img.shape

matrix = cv2.getRotationMatrix2D((0,0),0,0.5)
img2 = cv2.warpAffine(img1,matrix,(cols,rows))

SrcPoints = np.float32([[0,0],[0,150],[150,150]])
CanvasPoints = np.float32([[0,0],[0,150],[150,200]])

matrix = cv2.getAffineTransform(np.array(SrcPoints),
                                np.array(CanvasPoints))
print(matrix)
img3 = cv2.warpAffine(img2,matrix,(cols,rows))

plt.subplot(131)
plt.imshow(img1) 

plt.subplot(132)
plt.imshow(img2) 

plt.subplot(133)
plt.imshow(img3)
# Out:
# [[1.         0.         0.        ]
#  [0.33333333 1.         0.        ]]

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
rows,cols,_ = img.shape

plt.subplot(131)
plt.imshow(img1) 

plt.subplot(132)
plt.imshow(img1) 

plt.subplot(133)
plt.imshow(img1)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/pig.jpg")

img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
rows,cols,_ = img.shape

plt.subplot(311)
plt.imshow(img1) 

plt.subplot(312)
plt.imshow(img1) 

plt.subplot(313)
plt.imshow(img1)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/lena.jpeg")

img1=img.copy()

img1=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
img2 = np.uint8(np.clip((img1 + 20), 1, 254))
img3 = np.uint8(np.clip((1.5 * img1 ), 0, 254))


plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 

plt.subplot(223)
plt.imshow(img3,cmap=plt.cm.gray)

# %%
import numpy as np
import cv2
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/lena.jpeg")

img1=img.copy()
img2=img.copy()
img3=img.copy()
img1=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def SaltAndPepper(src,percetage):  
    SP_NoiseImg=src 
    SP_NoiseNum=int(percetage*src.shape[0]*src.shape[1]) 
    for i in range(SP_NoiseNum): 
        randX=random.random_integers(0,src.shape[0]-1) 
        randY=random.random_integers(0,src.shape[1]-1) 
        if random.random_integers(0,1)==0: 
            SP_NoiseImg[randX,randY]=0 
        else: 
            SP_NoiseImg[randX,randY]=255 
    return SP_NoiseImg

def addGaussianNoise(image,percetage): 
    G_Noiseimg = image 
    G_NoiseNum=int(percetage*image.shape[0]*image.shape[1]) 
    for i in range(G_NoiseNum): 
        temp_x = np.random.randint(20,40) 
        temp_y = np.random.randint(20,40) 
        G_Noiseimg[temp_x][temp_y] = 255 
    return G_Noiseimg

addGaussianNoise(img2,0.1)
addGaussianNoise(img3,0.1)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 

plt.subplot(223)
plt.imshow(img3,cmap=plt.cm.gray)

# %%
import numpy as np
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


img1=img.copy()
img2=img.copy()
img3=img.copy()


img2=skimage.util.random_noise(img2, mode="gaussian", clip=True)
img3=skimage.util.random_noise(img3, mode="s&p", clip=True)

plt.subplot(221)
plt.imshow(img1) 

plt.subplot(222)
plt.imshow(img2) 

plt.subplot(223)
plt.imshow(img3)

# %%
#演示增加高斯噪声
import numpy as np
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img1=img.copy()
img2=img.copy()

img2=skimage.util.random_noise(img2, mode="gaussian",  seed=None, clip=True,mean=0,var=0.01)

plt.subplot(221)
plt.imshow(img1) 

plt.subplot(222)
plt.imshow(img2) 

img3=img.copy()
img4=img.copy()

img3=skimage.util.random_noise(img3, mode="gaussian",  seed=None, clip=True,mean=0,var=0.04)
img4=skimage.util.random_noise(img4, mode="gaussian",  seed=None, clip=True,mean=0,var=0.09)

plt.subplot(223)
plt.imshow(img3) 

plt.subplot(224)
plt.imshow(img4)

# %%
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img1=img.copy()
img2=img.copy()

img2=skimage.util.random_noise(img2, mode="salt",  seed=None, clip=True)

plt.subplot(221)
plt.imshow(img1) 

plt.subplot(222)
plt.imshow(img2) 

img3=img.copy()
img4=img.copy()

img3=skimage.util.random_noise(img3, mode="pepper",  seed=None, clip=True)
img4=skimage.util.random_noise(img4, mode="s&p",  seed=None, clip=True)

plt.subplot(223)
plt.imshow(img3) 

plt.subplot(224)
plt.imshow(img4)

# %%
#演示中值滤波器的去噪效果
import numpy as np
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img1=img.copy()
img2=img.copy()

#原图为增加噪声的图
img1=skimage.util.random_noise(img1, mode="gaussian",  seed=None, clip=True,mean=0,var=0.01)

#medianBlur需要处理整数型
img1=np.uint8(img1*255)
img2=cv2.medianBlur(img1,3)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 
plt.title("gaussian noize")

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 
plt.title("medianBlur")
# Out:
# [[161 168 116 ... 122 195 184]
#  [201 200 178 ... 192 184 193]
#  [185 169 106 ... 177 183 190]
#  ...
#  [122 125 141 ... 177 146 199]
#  [162 160 163 ... 243 198 188]
#  [139  61 123 ... 171 214 240]]
# Text(0.5, 1.0, 'medianBlur')

# %%
#演示中值滤波器的模糊效果
import numpy as np
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img1=img.copy()
img2=img.copy()
img3=img.copy()
img4=img.copy()

#medianBlur需要处理整数型
img2=cv2.medianBlur(img2,3)
img3=cv2.medianBlur(img3,11)
img4=cv2.medianBlur(img4,19)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 
plt.title("Original image")

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 
plt.title("medianBlur n=3")

plt.subplot(223)
plt.imshow(img3,cmap=plt.cm.gray) 
plt.title("medianBlur n=11")

plt.subplot(224)
plt.imshow(img4,cmap=plt.cm.gray) 
plt.title("medianBlur n=19")

plt.tight_layout()

# %%
#演示高斯滤波器的去噪效果
import numpy as np
import cv2
import skimage
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img1=img.copy()
img2=img.copy()

#原图为增加噪声的图
img1=skimage.util.random_noise(img1, mode="gaussian",  seed=None, clip=True,mean=0,var=0.01)

#medianBlur需要处理整数型
img1=np.uint8(img1*255)
img2=cv2.GaussianBlur(img1,(7,7),0)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 
plt.title("gaussian noize")

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 
plt.title("gaussianBlur")
# Out:
# Text(0.5, 1.0, 'gaussianBlur')

# %%
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img1=img.copy()
img2=img.copy()
img3=img.copy()
img4=img.copy()

#原图为增加噪声的图
img1=skimage.util.random_noise(img1, mode="gaussian",  seed=None, clip=True,mean=0,var=0.01)
img1=np.uint8(img1*255)

#medianBlur需要处理整数型
img2=cv2.medianBlur(img1,11)
img3=cv2.GaussianBlur(img1,(11,11),0)
img4=cv2.bilateralFilter(img1,11,50,50)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 
plt.title("gaussian noize")

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 
plt.title("medianBlur n=11")

plt.subplot(223)
plt.imshow(img3,cmap=plt.cm.gray) 
plt.title("gaussianBlur n=11")

plt.subplot(224)
plt.imshow(img4,cmap=plt.cm.gray) 
plt.title("bilateralFilter n=11")

plt.tight_layout()

# %%
from scipy import * 
from matplotlib import pyplot as plt 
img=cv2.imread("../picture/bigpig.jpeg")
img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

img1=img.copy()
img2=img.copy()
img3=img.copy()
img4=img.copy()

#原图为增加噪声的图
img1=skimage.util.random_noise(img1, mode="gaussian",  seed=None, clip=True,mean=0,var=0.01)
img1=np.uint8(img1*255)

img2=cv2.bilateralFilter(img1,11,10,10)
img3=cv2.bilateralFilter(img1,11,50,50)
img4=cv2.bilateralFilter(img1,11,100,100)

plt.subplot(221)
plt.imshow(img1,cmap=plt.cm.gray) 
plt.title("gaussian noize")

plt.subplot(222)
plt.imshow(img2,cmap=plt.cm.gray) 
plt.title("bilateralFilter (10,10)")

plt.subplot(223)
plt.imshow(img3,cmap=plt.cm.gray) 
plt.title("bilateralFilter (50,50)")

plt.subplot(224)
plt.imshow(img4,cmap=plt.cm.gray) 
plt.title("bilateralFilter (100,100)")

plt.tight_layout()
