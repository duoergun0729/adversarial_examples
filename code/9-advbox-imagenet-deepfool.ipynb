# %% [raw]
# 介绍如何在tensorflow环境下，使用DeepFool算法攻击基于Inception数据集预训练的alexnet模型。

# %% [markdown]
# Jupyter notebook中使用Anaconda中的环境需要单独配置，默认情况下使用的是系统默认的Python环境，以使用advbox环境为例。
# 首先在默认系统环境下执行以下命令，安装ipykernel。
#
#     conda install ipykernel
#     conda install -n advbox ipykernel
#
# 在advbox环境下激活，这样启动后就可以在界面上看到advbox了。
#
#     python -m ipykernel install --user --name advbox --display-name advbox

# %%
import logging
logging.basicConfig(level=logging.INFO,format="%(filename)s[line:%(lineno)d] %(levelname)s %(message)s")
logger=logging.getLogger(__name__)

import sys
#添加系统路径
sys.path.append("../AdvBox/")

import numpy as np
from PIL import Image
#pip install Pillow
from advbox.adversary import Adversary
from advbox.attacks.deepfool import DeepFoolAttack
from advbox.models.tensorflow import TensorflowModel
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
from tools import show_images_diff,show_d

# %%
#定义被攻击的图片
imagename="../AdvBox/tutorials/cropped_panda.jpg"
#从'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'下载并解压到当前路径
dirname="../AdvBox/classify_image_graph_def.pb"

# %%
#加载解码的图像 这里是个大坑 tf提供的imagenet预训练好的模型pb文件中 包含针对图像的预处理环节 即解码jpg文件 这部分没有梯度
#需要直接处理解码后的数据
image=np.array(Image.open(imagename).convert('RGB').resize((224,224))).astype(np.float32)


orig=image.copy().astype(np.uint8) 
#[224,224,3]->[1,224,224,3]
image=np.expand_dims(image, axis=0)

session=tf.Session()

def create_graph(dirname):
    with tf.gfile.FastGFile(dirname, 'rb') as f:
        graph_def = session.graph_def
        graph_def.ParseFromString(f.read())

        _ = tf.import_graph_def(graph_def, name='')

create_graph(dirname)

# 初始化参数  非常重要
session.run(tf.global_variables_initializer())

tensorlist=[n.name for n in session.graph_def.node]

#输出全部tensor
#logger.info(tensorlist)


#获取logits
logits=session.graph.get_tensor_by_name('softmax/logits:0')

x = session.graph.get_tensor_by_name('ExpandDims:0')

# advbox demo
# 因为原始数据没有归一化  所以bounds=(0, 255)
m = TensorflowModel(
    session,
    x,
    None,
    logits,
    None,
    bounds=(0, 255),
    channel_axis=3,
    preprocess=None)

#实例化DeepFool 进行定向攻击 
attack = DeepFoolAttack(m)
attack_config = {"iterations": 100, "overshoot": 0.05}

adversary = Adversary(image,None)
#麦克风
tlabel = 651
adversary.set_target(is_targeted_attack=True, target_label=tlabel)

# DeepFool targeted attack
adversary = attack(adversary, **attack_config)

if adversary.is_successful():
    print(
        'attack success, adversarial_label=%d'
        % (adversary.adversarial_label) )

    #对抗样本保存在adversary.adversarial_example
    adversary_image=np.copy(adversary.adversarial_example)
    #强制类型转换 之前是float 现在要转换成int8

    adv = np.array(adversary_image).astype("uint8")[0]

 

print("DeepFool attack done")
# Out:
# tf_logging.py[line:125] WARNING From <ipython-input-3-1b0379bff264>:13: __init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# tensorflow.py[line:63] INFO self._input_shape:(Dimension(None), Dimension(None), Dimension(3))
# tensorflow.py[line:65] INFO init grads[1008]...
# tensorflow.py[line:72] INFO Finish TensorflowPBModel init
# base.py[line:87] INFO adversary:
#          original_label: 169
#          target_label: 651
#          is_targeted_attack: True
# deepfool.py[line:54] INFO min_=0, max_=255
# deepfool.py[line:73] INFO select label:651
# tensorflow.py[line:127] INFO Start to get _grads[169]
# tensorflow.py[line:129] INFO Finish to get _grads[169]
# tensorflow.py[line:127] INFO Start to get _grads[651]
# tensorflow.py[line:129] INFO Finish to get _grads[651]
# deepfool.py[line:121] INFO iteration=0, f[pre_label]=7.55900001526, f[target_label]=1.0127903223, f[adv_label]=7.55900001526, pre_label=169, adv_label=169
# deepfool.py[line:121] INFO iteration=1, f[pre_label]=5.68743944168, f[target_label]=1.22994732857, f[adv_label]=5.68743944168, pre_label=169, adv_label=169
# deepfool.py[line:121] INFO iteration=2, f[pre_label]=4.50030088425, f[target_label]=1.51713454723, f[adv_label]=5.89978694916, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=3, f[pre_label]=3.4198050499, f[target_label]=1.91534435749, f[adv_label]=6.42019271851, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=4, f[pre_label]=2.54390358925, f[target_label]=2.11005210876, f[adv_label]=6.81832790375, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=5, f[pre_label]=2.30282402039, f[target_label]=2.25539016724, f[adv_label]=6.95708465576, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=6, f[pre_label]=2.27069592476, f[target_label]=2.27165317535, f[adv_label]=6.97634983063, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=7, f[pre_label]=2.270008564, f[target_label]=2.27196788788, f[adv_label]=6.97676181793, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=8, f[pre_label]=2.26860046387, f[target_label]=2.27261590958, f[adv_label]=6.97759532928, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=9, f[pre_label]=2.26574277878, f[target_label]=2.27395153046, f[adv_label]=6.97931098938, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=10, f[pre_label]=2.25990223885, f[target_label]=2.27679634094, f[adv_label]=6.98264598846, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=11, f[pre_label]=2.2480442524, f[target_label]=2.28262543678, f[adv_label]=6.9896697998, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=12, f[pre_label]=2.2240049839, f[target_label]=2.29440832138, f[adv_label]=7.0046710968, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=13, f[pre_label]=2.17644834518, f[target_label]=2.31908202171, f[adv_label]=7.03435707092, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=14, f[pre_label]=2.07980823517, f[target_label]=2.36693239212, f[adv_label]=7.09599494934, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=15, f[pre_label]=1.88521206379, f[target_label]=2.4523396492, f[adv_label]=7.18830871582, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=16, f[pre_label]=1.54662084579, f[target_label]=2.62185668945, f[adv_label]=7.30594062805, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=17, f[pre_label]=1.11112749577, f[target_label]=2.87788772583, f[adv_label]=7.44148540497, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=18, f[pre_label]=0.795788884163, f[target_label]=2.98759651184, f[adv_label]=7.80824375153, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=19, f[pre_label]=0.488332271576, f[target_label]=3.34193706512, f[adv_label]=7.73452854156, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=20, f[pre_label]=0.571381926537, f[target_label]=3.94349527359, f[adv_label]=7.86538314819, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=21, f[pre_label]=-0.00628021731973, f[target_label]=3.91664433479, f[adv_label]=8.01131820679, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=22, f[pre_label]=0.801899492741, f[target_label]=5.10866785049, f[adv_label]=8.36767482758, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=23, f[pre_label]=-0.0775457769632, f[target_label]=5.49416971207, f[adv_label]=8.26460838318, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=24, f[pre_label]=0.329963892698, f[target_label]=6.48067522049, f[adv_label]=8.90904998779, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=25, f[pre_label]=-0.130349501967, f[target_label]=8.31915378571, f[adv_label]=9.01333618164, pre_label=169, adv_label=75
# deepfool.py[line:121] INFO iteration=26, f[pre_label]=-0.232765421271, f[target_label]=10.9849853516, f[adv_label]=10.9849853516, pre_label=169, adv_label=651
# attack success, adversarial_label=651
# DeepFool attack done

# %%
#显示原始图片  抵抗样本 以及两张图之间的差异  其中灰色代表没有差异的像素点
show_images_diff(orig,adversary.original_label,adv,adversary.adversarial_label)
# Out:
# l0=90081 l2=69971.9882382

# %%
from tools import show_d
show_d(np.expand_dims(orig, axis=0)/256.0,np.expand_dims(adv, axis=0)/256.0)
# Out:
# Image Size 150528 Shape (1, 224, 224, 3)
# Noise L_0 norm: 90081 60%
# Noise L_2 norm: 1.619139447 1%
# Noise L_inf norm: 0.046875 1%
# (60, 1, 1)
