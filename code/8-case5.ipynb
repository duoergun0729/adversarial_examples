# %%
#内嵌画图
# %matplotlib inline
#调试开关
import logging
#logging.basicConfig(level=logging.INFO,format="%(filename)s[line:%(lineno)d] %(levelname)s %(message)s")
#logger=logging.getLogger(__name__)

import sys

#添加系统路径
sys.path.append("../AdvBox/")

import torch
import torchvision
from torchvision import datasets, transforms
from torch.autograd import Variable
import torch.utils.data.dataloader as Data
from advbox.adversary import Adversary
from advbox.attacks.gradient_method import FGSM
from advbox.models.pytorch import PytorchModel
from tutorials.mnist_model_pytorch import Net

# 自适应使用GPU还是CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# train_data: torch.Size([60000, 28, 28])
# train_labels: torch.Size([60000])
# test_data: torch.Size([10000, 28, 28])

# %%
import torch.nn as nn
import matplotlib.pyplot as plt

class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Conv2d(1,64,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
            nn.Conv2d(64,128,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,stride=2),
        )
        self.decoder = nn.Sequential(
            nn.Upsample(scale_factor=2,mode="nearest"),
            nn.Conv2d(128,64,kernel_size=3,stride=1,padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2,mode="nearest"),
            nn.Conv2d(64,1,kernel_size=3,stride=1,padding=1),
        )

    def forward(self, x):
        output = self.encoder(x)
        output = self.decoder(output)
        return output

autoencoder = AutoEncoder().to(device)

optimizer = torch.optim.Adam(autoencoder.parameters(), lr=0.01)
loss_func = nn.MSELoss()

#使用MNIST训练数据集 

train_data=datasets.MNIST('../AdvBox/tutorials/mnist-pytorch/data', train=True, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
    ]))

train_loader = torch.utils.data.DataLoader(
    dataset=train_data,
    batch_size=128, shuffle=True)

#迭代训练10轮
for epoch in range(20):

    for i, data in enumerate(train_loader):
        inputs, labels = data
                    
        inputs, labels = inputs.to(device), labels.to(device)
        
        #增加噪声
        inputs_noise=inputs+0.1*torch.randn(inputs.shape).to(device)
        inputs_noise=torch.clamp(inputs_noise,0.0,1.0)
        
        #output = autoencoder(inputs)
        #encoded, decoded = autoencoder(inputs_noise)
        output = autoencoder(inputs_noise)

        loss = loss_func(output, inputs)      
        optimizer.zero_grad()               
        loss.backward()                     
        optimizer.step()                  

        if (i % 100 == 0) and ( i > 0 ):
            print("Epoch={} batch={} loss={}".format(epoch,i, loss.data.cpu().numpy()))
# Out:
# Epoch=0 batch=100 loss=0.0360135696828
# Epoch=0 batch=200 loss=0.0240466762334
# Epoch=0 batch=300 loss=0.0190817210823
# Epoch=0 batch=400 loss=0.016608748585
# Epoch=1 batch=100 loss=0.0138044580817
# Epoch=1 batch=200 loss=0.0128854429349
# Epoch=1 batch=300 loss=0.0124944038689
# Epoch=1 batch=400 loss=0.0109587656334
# Epoch=2 batch=100 loss=0.0110200578347
# Epoch=2 batch=200 loss=0.0106793874875
# Epoch=2 batch=300 loss=0.00996408239007
# Epoch=2 batch=400 loss=0.0106243239716
# Epoch=3 batch=100 loss=0.00986938923597
# Epoch=3 batch=200 loss=0.00985191483051
# Epoch=3 batch=300 loss=0.00996092427522
# Epoch=3 batch=400 loss=0.0096589429304
# Epoch=4 batch=100 loss=0.00975240394473
# Epoch=4 batch=200 loss=0.00950953178108
# Epoch=4 batch=300 loss=0.00894741527736
# Epoch=4 batch=400 loss=0.00893811229616
# Epoch=5 batch=100 loss=0.00924315303564
# Epoch=5 batch=200 loss=0.0088550504297
# Epoch=5 batch=300 loss=0.00909268576652
# Epoch=5 batch=400 loss=0.00888279732317
# Epoch=6 batch=100 loss=0.00893933326006
# Epoch=6 batch=200 loss=0.00785822048783
# Epoch=6 batch=300 loss=0.00807840656489
# Epoch=6 batch=400 loss=0.00956307165325
# Epoch=7 batch=100 loss=0.00799962878227
# Epoch=7 batch=200 loss=0.00868190079927
# Epoch=7 batch=300 loss=0.00782563351095
# Epoch=7 batch=400 loss=0.00769136380404
# Epoch=8 batch=100 loss=0.00844289548695
# Epoch=8 batch=200 loss=0.00694535532966
# Epoch=8 batch=300 loss=0.00756047759205
# Epoch=8 batch=400 loss=0.008041751571
# Epoch=9 batch=100 loss=0.00729619618505
# Epoch=9 batch=200 loss=0.00750382337719
# Epoch=9 batch=300 loss=0.00777751579881
# Epoch=9 batch=400 loss=0.00710090948269
# Epoch=10 batch=100 loss=0.00756037002429
# Epoch=10 batch=200 loss=0.00751478085294
# Epoch=10 batch=300 loss=0.00775606837124
# Epoch=10 batch=400 loss=0.00735081080347
# Epoch=11 batch=100 loss=0.00719679007307
# Epoch=11 batch=200 loss=0.00720364972949
# Epoch=11 batch=300 loss=0.0078052347526
# Epoch=11 batch=400 loss=0.007156658452
# Epoch=12 batch=100 loss=0.00718997698277
# Epoch=12 batch=200 loss=0.00664208782837
# Epoch=12 batch=300 loss=0.00734786782414
# Epoch=12 batch=400 loss=0.00753492163494
# Epoch=13 batch=100 loss=0.00779954530299
# Epoch=13 batch=200 loss=0.00727568613365
# Epoch=13 batch=300 loss=0.00818073470145
# Epoch=13 batch=400 loss=0.00741611700505
# Epoch=14 batch=100 loss=0.0074438280426
# Epoch=14 batch=200 loss=0.00698716426268
# Epoch=14 batch=300 loss=0.00688620842993
# Epoch=14 batch=400 loss=0.00765312183648
# Epoch=15 batch=100 loss=0.00709542958066
# Epoch=15 batch=200 loss=0.0071956217289
# Epoch=15 batch=300 loss=0.00694432668388
# Epoch=15 batch=400 loss=0.00760077638552
# Epoch=16 batch=100 loss=0.00713756633922
# Epoch=16 batch=200 loss=0.00701818661764
# Epoch=16 batch=300 loss=0.00653168791905
# Epoch=16 batch=400 loss=0.00680025294423
# Epoch=17 batch=100 loss=0.00680208252743
# Epoch=17 batch=200 loss=0.00721895135939
# Epoch=17 batch=300 loss=0.00657265540212
# Epoch=17 batch=400 loss=0.00680997222662
# Epoch=18 batch=100 loss=0.00714309792966
# Epoch=18 batch=200 loss=0.00648493180051
# Epoch=18 batch=300 loss=0.0103483321145
# Epoch=18 batch=400 loss=0.00699126301333
# Epoch=19 batch=100 loss=0.00712658977136
# Epoch=19 batch=200 loss=0.0074752564542
# Epoch=19 batch=300 loss=0.00657633878291
# Epoch=19 batch=400 loss=0.00702550215647

# %% [markdown]
# # 验证自编码器去噪对模型识别的影响

# %%
import numpy as np


TOTAL_NUM = 1000
pretrained_model="../AdvBox/tutorials/mnist-pytorch/net.pth"


#使用MNIST测试数据集 随机挑选TOTAL_NUM个
# Pytorch下的MNIST数据集默认就是归一化了
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../AdvBox/tutorials/mnist-pytorch/data', train=False, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
    ])),
    batch_size=1, shuffle=True)

# Define what device we are using
logging.info("CUDA Available: {}".format(torch.cuda.is_available()))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the network
model = Net().to(device)

# Load the pretrained model
model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

# Set the model in evaluation mode. In this case this is for the Dropout layers
model.eval()

# use test data to generate adversarial examples
total_count = 0

#去噪前正确识别个数
pre_count=0

#去噪后正确识别个数
decoded_count = 0



for i, data in enumerate(test_loader):
    inputs, labels = data
    inputs, labels = inputs.to(device), labels.to(device)

    total_count += 1
    
    #去噪前
    pre_label=np.argmax(model(inputs).data.cpu().numpy())
    
    if pre_label == labels[0]:
        pre_count+=1
        
    
    
    
    #使用自编码器去噪
    output = autoencoder(inputs)
    output=output.view(1,1,28,28)
    
    decoded_label=np.argmax(model(output).data.cpu().numpy())
        
        
    if decoded_label == labels[0]:
        decoded_count+=1
    
       

    if total_count >= TOTAL_NUM:
        print(
            "[TEST_DATASET]: pre_count=%d, total_count=%d, pre_count_rate=%f  decoded_count=%d decoded_count_rate=%f"
            % (pre_count, total_count, float(pre_count) / total_count,decoded_count, float(decoded_count) / total_count  ) 
             )
        break
# Out:
# [TEST_DATASET]: pre_count=991, total_count=1000, pre_count_rate=0.991000  decoded_count=982 decoded_count_rate=0.982000

# %% [markdown]
# # 使用自编码器过滤噪音

# %%
import numpy as np


TOTAL_NUM = 1000
pretrained_model="../AdvBox/tutorials/mnist-pytorch/net.pth"
loss_func = torch.nn.CrossEntropyLoss()

#使用MNIST测试数据集 随机挑选TOTAL_NUM个
# Pytorch下的MNIST数据集默认就是归一化了
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../AdvBox/tutorials/mnist-pytorch/data', train=False, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
    ])),
    batch_size=1, shuffle=True)

# Define what device we are using
logging.info("CUDA Available: {}".format(torch.cuda.is_available()))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the network
model = Net().to(device)

# Load the pretrained model
model.load_state_dict(torch.load(pretrained_model, map_location='cpu'))

# Set the model in evaluation mode. In this case this is for the Dropout layers
model.eval()

# advbox demo
m = PytorchModel(
    model, loss_func,(0, 1),
    channel_axis=1)

#实例化FGSM
attack = FGSM(m)
#设置攻击步长为0.1
attack_config = {"epsilons": 0.01}

# use test data to generate adversarial examples
total_count = 0
# 去噪前的攻击成功个数
fooling_count = 0
# 去噪后的攻击成功个数
decoded_fooling_count = 0

#记录原始数据经过自编码器去噪后可以正常识别的个数
decoded_count = 0



for i, data in enumerate(test_loader):
    inputs, labels = data
    inputs, labels=inputs.numpy(),labels.numpy()
    
    

    total_count += 1
    adversary = Adversary(inputs, labels[0])

    # FGSM non-targeted attack
    adversary = attack(adversary, **attack_config)

    if adversary.is_successful():
        fooling_count += 1
        print(
            'attack success, original_label=%d, adversarial_label=%d, count=%d'
            % (labels, adversary.adversarial_label, total_count))
         
        #对抗样本保存在adversary.adversarial_example
        #adversary_image=np.copy(adversary.adversarial_example[0])
        adversary_image = Variable(torch.from_numpy(np.copy(adversary.adversarial_example)).to(device).float())
        pre_label=np.argmax(model(adversary_image).data.cpu().numpy())
        
        
        #使用自编码器去噪
        output = autoencoder(adversary_image)
            
        #print(decoded.shape)
        output=output.view(1,1,28,28)
        #print(decoded.shape)
        
        decoded_label=np.argmax(model(output).data.cpu().numpy())
        
        
        if decoded_label != labels[0]:
            print("orig_label={} adv_label={} decoded_label={}".format(labels[0],pre_label,decoded_label))
            decoded_fooling_count+=1
            
            
    else:
        print('attack failed, original_label=%d, count=%d' %
              (labels, total_count))

    if total_count >= TOTAL_NUM:
        print(
            "[TEST_DATASET]: fooling_count=%d, total_count=%d, fooling_rate=%f decoded_fooling_count=%d  decoded_fooling_count_rate=%f"
            % (fooling_count, total_count, float(fooling_count) / total_count,decoded_fooling_count,float(decoded_fooling_count) / total_count))
        break
print("fgsm attack done")
# Out:
# cuda
# attack success, original_label=5, adversarial_label=0, count=1
# attack success, original_label=9, adversarial_label=4, count=2
# attack success, original_label=2, adversarial_label=7, count=3
# attack success, original_label=3, adversarial_label=5, count=4
# attack success, original_label=4, adversarial_label=7, count=5
# attack success, original_label=5, adversarial_label=8, count=6
# attack success, original_label=2, adversarial_label=8, count=7
# attack success, original_label=4, adversarial_label=9, count=8
# orig_label=4 adv_label=9 decoded_label=9
# attack success, original_label=4, adversarial_label=9, count=9
# attack success, original_label=1, adversarial_label=4, count=10
# attack success, original_label=9, adversarial_label=4, count=11
# attack success, original_label=8, adversarial_label=5, count=12
# attack success, original_label=0, adversarial_label=6, count=13
# attack success, original_label=6, adversarial_label=0, count=14
# attack success, original_label=2, adversarial_label=7, count=15
# attack success, original_label=7, adversarial_label=4, count=16
# attack success, original_label=2, adversarial_label=1, count=17
# attack success, original_label=9, adversarial_label=4, count=18
# attack success, original_label=4, adversarial_label=9, count=19
# attack success, original_label=5, adversarial_label=3, count=20
# attack success, original_label=4, adversarial_label=0, count=21
# attack success, original_label=2, adversarial_label=0, count=22
# attack success, original_label=4, adversarial_label=9, count=23
# attack success, original_label=5, adversarial_label=8, count=24
# attack success, original_label=6, adversarial_label=5, count=25
# attack success, original_label=1, adversarial_label=4, count=26
# attack success, original_label=3, adversarial_label=5, count=27
# attack success, original_label=3, adversarial_label=5, count=28
# attack success, original_label=2, adversarial_label=8, count=29
# attack success, original_label=8, adversarial_label=9, count=30
# attack success, original_label=0, adversarial_label=6, count=31
# attack success, original_label=3, adversarial_label=5, count=32
# attack success, original_label=8, adversarial_label=3, count=33
# attack success, original_label=4, adversarial_label=2, count=34
# attack success, original_label=2, adversarial_label=7, count=35
# attack success, original_label=0, adversarial_label=2, count=36
# attack success, original_label=9, adversarial_label=4, count=37
# attack success, original_label=5, adversarial_label=8, count=38
# attack success, original_label=2, adversarial_label=3, count=39
# attack success, original_label=0, adversarial_label=9, count=40
# attack success, original_label=5, adversarial_label=9, count=41
# attack success, original_label=3, adversarial_label=8, count=42
# attack success, original_label=3, adversarial_label=8, count=43
# attack success, original_label=6, adversarial_label=0, count=44
# attack success, original_label=3, adversarial_label=8, count=45
# attack success, original_label=7, adversarial_label=9, count=46
# attack success, original_label=4, adversarial_label=9, count=47
# attack success, original_label=5, adversarial_label=8, count=48
# attack success, original_label=1, adversarial_label=4, count=49
# attack success, original_label=5, adversarial_label=9, count=50
# attack success, original_label=8, adversarial_label=5, count=51
# orig_label=8 adv_label=5 decoded_label=5
# attack success, original_label=7, adversarial_label=3, count=52
# attack success, original_label=2, adversarial_label=7, count=53
# attack success, original_label=7, adversarial_label=9, count=54
# attack success, original_label=2, adversarial_label=1, count=55
# attack success, original_label=5, adversarial_label=3, count=56
# attack success, original_label=2, adversarial_label=0, count=57
# attack success, original_label=1, adversarial_label=4, count=58
# attack success, original_label=9, adversarial_label=3, count=59
# attack success, original_label=6, adversarial_label=8, count=60
# attack success, original_label=0, adversarial_label=2, count=61
# attack success, original_label=5, adversarial_label=9, count=62
# attack success, original_label=7, adversarial_label=9, count=63
# attack success, original_label=1, adversarial_label=4, count=64
# attack success, original_label=0, adversarial_label=5, count=65
# attack success, original_label=8, adversarial_label=2, count=66
# attack success, original_label=5, adversarial_label=9, count=67
# attack success, original_label=3, adversarial_label=5, count=68
# attack success, original_label=8, adversarial_label=9, count=69
# attack success, original_label=3, adversarial_label=8, count=70
# attack success, original_label=7, adversarial_label=9, count=71
# attack success, original_label=6, adversarial_label=5, count=72
# attack success, original_label=8, adversarial_label=3, count=73
# attack success, original_label=7, adversarial_label=8, count=74
# attack success, original_label=5, adversarial_label=1, count=75
# attack success, original_label=2, adversarial_label=8, count=76
# attack success, original_label=8, adversarial_label=0, count=77
# attack success, original_label=9, adversarial_label=7, count=78
# orig_label=9 adv_label=7 decoded_label=7
# attack success, original_label=3, adversarial_label=5, count=79
# attack success, original_label=3, adversarial_label=5, count=80
# attack success, original_label=1, adversarial_label=4, count=81
# attack success, original_label=5, adversarial_label=9, count=82
# attack success, original_label=1, adversarial_label=7, count=83
# attack success, original_label=2, adversarial_label=7, count=84
# attack success, original_label=6, adversarial_label=8, count=85
# attack success, original_label=8, adversarial_label=3, count=86
# attack success, original_label=4, adversarial_label=7, count=87
# attack success, original_label=2, adversarial_label=7, count=88
# attack success, original_label=3, adversarial_label=9, count=89
# attack success, original_label=7, adversarial_label=9, count=90
# attack success, original_label=9, adversarial_label=3, count=91
# attack success, original_label=0, adversarial_label=6, count=92
# attack success, original_label=4, adversarial_label=7, count=93
# attack success, original_label=6, adversarial_label=5, count=94
# attack success, original_label=2, adversarial_label=8, count=95
# attack success, original_label=9, adversarial_label=7, count=96
# orig_label=9 adv_label=7 decoded_label=7
# attack success, original_label=9, adversarial_label=4, count=97
# attack success, original_label=7, adversarial_label=9, count=98
# attack success, original_label=2, adversarial_label=8, count=99
# attack success, original_label=1, adversarial_label=4, count=100
# attack success, original_label=8, adversarial_label=0, count=101
# attack success, original_label=9, adversarial_label=4, count=102
# attack success, original_label=7, adversarial_label=2, count=103
# orig_label=7 adv_label=2 decoded_label=2
# attack success, original_label=8, adversarial_label=2, count=104
# attack success, original_label=8, adversarial_label=4, count=105
# attack success, original_label=7, adversarial_label=9, count=106
# attack success, original_label=4, adversarial_label=9, count=107
# attack success, original_label=3, adversarial_label=5, count=108
# attack success, original_label=7, adversarial_label=9, count=109
# attack success, original_label=8, adversarial_label=7, count=110
# attack success, original_label=4, adversarial_label=9, count=111
# attack success, original_label=9, adversarial_label=5, count=112
# attack success, original_label=2, adversarial_label=0, count=113
# attack success, original_label=6, adversarial_label=5, count=114
# attack success, original_label=1, adversarial_label=7, count=115
# attack success, original_label=3, adversarial_label=5, count=116
# attack success, original_label=8, adversarial_label=0, count=117
# attack success, original_label=1, adversarial_label=4, count=118
# attack success, original_label=4, adversarial_label=2, count=119
# attack success, original_label=1, adversarial_label=4, count=120
# attack success, original_label=8, adversarial_label=2, count=121
# attack success, original_label=6, adversarial_label=8, count=122
# attack success, original_label=6, adversarial_label=5, count=123
# attack success, original_label=1, adversarial_label=4, count=124
# attack success, original_label=1, adversarial_label=7, count=125
# attack success, original_label=2, adversarial_label=7, count=126
# attack success, original_label=2, adversarial_label=7, count=127
# attack success, original_label=2, adversarial_label=4, count=128
# attack success, original_label=7, adversarial_label=9, count=129
# attack success, original_label=7, adversarial_label=9, count=130
# attack success, original_label=7, adversarial_label=0, count=131
# attack success, original_label=2, adversarial_label=8, count=132
# attack success, original_label=4, adversarial_label=8, count=133
# attack success, original_label=4, adversarial_label=7, count=134
# attack success, original_label=5, adversarial_label=0, count=135
# attack success, original_label=8, adversarial_label=9, count=136
# attack success, original_label=3, adversarial_label=5, count=137
# attack success, original_label=7, adversarial_label=5, count=138
# attack success, original_label=7, adversarial_label=9, count=139
# attack success, original_label=9, adversarial_label=4, count=140
# attack success, original_label=4, adversarial_label=9, count=141
# attack success, original_label=6, adversarial_label=5, count=142
# attack success, original_label=2, adversarial_label=3, count=143
# attack success, original_label=4, adversarial_label=1, count=144
# attack success, original_label=2, adversarial_label=7, count=145
# attack success, original_label=9, adversarial_label=0, count=146
# attack success, original_label=9, adversarial_label=4, count=147
# attack success, original_label=5, adversarial_label=6, count=148
# attack success, original_label=8, adversarial_label=3, count=149
# attack success, original_label=9, adversarial_label=4, count=150
# attack success, original_label=8, adversarial_label=3, count=151
# attack success, original_label=0, adversarial_label=9, count=152
# attack success, original_label=5, adversarial_label=9, count=153
# attack success, original_label=1, adversarial_label=4, count=154
# attack success, original_label=3, adversarial_label=5, count=155
# attack success, original_label=5, adversarial_label=3, count=156
# attack success, original_label=9, adversarial_label=8, count=157
# attack success, original_label=9, adversarial_label=4, count=158
# attack success, original_label=2, adversarial_label=1, count=159
# attack success, original_label=1, adversarial_label=4, count=160
# attack success, original_label=5, adversarial_label=3, count=161
# attack success, original_label=3, adversarial_label=7, count=162
# attack success, original_label=0, adversarial_label=2, count=163
# attack success, original_label=0, adversarial_label=5, count=164
# attack success, original_label=6, adversarial_label=8, count=165
# attack success, original_label=3, adversarial_label=5, count=166
# attack success, original_label=9, adversarial_label=4, count=167
# orig_label=9 adv_label=4 decoded_label=1
# attack success, original_label=6, adversarial_label=0, count=168
# attack success, original_label=0, adversarial_label=6, count=169
# attack success, original_label=7, adversarial_label=9, count=170
# attack success, original_label=6, adversarial_label=0, count=171
# attack success, original_label=4, adversarial_label=7, count=172
# orig_label=4 adv_label=7 decoded_label=7
# attack success, original_label=6, adversarial_label=5, count=173
# attack success, original_label=4, adversarial_label=9, count=174
# attack success, original_label=1, adversarial_label=7, count=175
# attack success, original_label=5, adversarial_label=8, count=176
# attack success, original_label=5, adversarial_label=9, count=177
# attack success, original_label=7, adversarial_label=3, count=178
# attack success, original_label=3, adversarial_label=5, count=179
# attack success, original_label=2, adversarial_label=7, count=180
# attack success, original_label=9, adversarial_label=4, count=181
# attack success, original_label=7, adversarial_label=9, count=182
# attack success, original_label=9, adversarial_label=5, count=183
# attack success, original_label=7, adversarial_label=9, count=184
# attack success, original_label=2, adversarial_label=0, count=185
# attack success, original_label=2, adversarial_label=1, count=186
# attack success, original_label=5, adversarial_label=3, count=187
# attack success, original_label=2, adversarial_label=8, count=188
# attack success, original_label=8, adversarial_label=9, count=189
# attack success, original_label=2, adversarial_label=3, count=190
# attack success, original_label=4, adversarial_label=9, count=191
# attack success, original_label=0, adversarial_label=5, count=192
# attack success, original_label=9, adversarial_label=8, count=193
# attack success, original_label=5, adversarial_label=8, count=194
# attack success, original_label=6, adversarial_label=0, count=195
# attack success, original_label=8, adversarial_label=5, count=196
# attack success, original_label=6, adversarial_label=5, count=197
# attack success, original_label=5, adversarial_label=3, count=198
# attack success, original_label=4, adversarial_label=9, count=199
# attack success, original_label=9, adversarial_label=4, count=200
# attack success, original_label=4, adversarial_label=9, count=201
# attack success, original_label=6, adversarial_label=0, count=202
# attack success, original_label=4, adversarial_label=9, count=203
# attack success, original_label=6, adversarial_label=0, count=204
# attack success, original_label=1, adversarial_label=4, count=205
# attack success, original_label=3, adversarial_label=5, count=206
# attack success, original_label=8, adversarial_label=9, count=207
# orig_label=8 adv_label=9 decoded_label=9
# attack success, original_label=8, adversarial_label=9, count=208
# orig_label=8 adv_label=9 decoded_label=9
# attack success, original_label=4, adversarial_label=7, count=209
# attack success, original_label=5, adversarial_label=8, count=210
# attack success, original_label=2, adversarial_label=7, count=211
# attack success, original_label=0, adversarial_label=9, count=212
# attack success, original_label=1, adversarial_label=7, count=213
# attack success, original_label=1, adversarial_label=4, count=214
# attack success, original_label=8, adversarial_label=5, count=215
# attack success, original_label=8, adversarial_label=0, count=216
# attack success, original_label=3, adversarial_label=9, count=217
# attack success, original_label=7, adversarial_label=1, count=218
# attack success, original_label=6, adversarial_label=4, count=219
# attack success, original_label=0, adversarial_label=5, count=220
# attack success, original_label=3, adversarial_label=8, count=221
# attack success, original_label=3, adversarial_label=8, count=222
# attack success, original_label=8, adversarial_label=9, count=223
# attack success, original_label=0, adversarial_label=4, count=224
# attack success, original_label=4, adversarial_label=9, count=225
# attack success, original_label=4, adversarial_label=9, count=226
# attack success, original_label=7, adversarial_label=9, count=227
# attack success, original_label=6, adversarial_label=5, count=228
# attack success, original_label=6, adversarial_label=0, count=229
# attack success, original_label=6, adversarial_label=5, count=230
# attack success, original_label=9, adversarial_label=4, count=231
# attack success, original_label=2, adversarial_label=7, count=232
# attack success, original_label=8, adversarial_label=0, count=233
# attack success, original_label=7, adversarial_label=1, count=234
# attack success, original_label=4, adversarial_label=9, count=235
# attack success, original_label=4, adversarial_label=8, count=236
# attack success, original_label=5, adversarial_label=9, count=237
# attack success, original_label=7, adversarial_label=9, count=238
# attack success, original_label=8, adversarial_label=5, count=239
# attack success, original_label=7, adversarial_label=9, count=240
# attack success, original_label=2, adversarial_label=7, count=241
# attack success, original_label=8, adversarial_label=9, count=242
# attack success, original_label=1, adversarial_label=8, count=243
# attack success, original_label=3, adversarial_label=9, count=244
# orig_label=3 adv_label=9 decoded_label=9
# attack success, original_label=2, adversarial_label=7, count=245
# attack success, original_label=6, adversarial_label=5, count=246
# attack success, original_label=7, adversarial_label=1, count=247
# attack success, original_label=8, adversarial_label=2, count=248
# orig_label=8 adv_label=2 decoded_label=1
# attack success, original_label=2, adversarial_label=0, count=249
# attack success, original_label=5, adversarial_label=0, count=250
# attack success, original_label=1, adversarial_label=4, count=251
# attack success, original_label=2, adversarial_label=7, count=252
# attack success, original_label=4, adversarial_label=6, count=253
# orig_label=4 adv_label=6 decoded_label=6
# attack success, original_label=8, adversarial_label=5, count=254
# attack success, original_label=3, adversarial_label=5, count=255
# attack success, original_label=9, adversarial_label=4, count=256
# attack success, original_label=6, adversarial_label=0, count=257
# attack success, original_label=6, adversarial_label=8, count=258
# attack success, original_label=3, adversarial_label=9, count=259
# attack success, original_label=2, adversarial_label=8, count=260
# attack success, original_label=7, adversarial_label=9, count=261
# attack success, original_label=1, adversarial_label=7, count=262
# attack success, original_label=4, adversarial_label=8, count=263
# attack success, original_label=6, adversarial_label=0, count=264
# attack success, original_label=8, adversarial_label=9, count=265
# attack success, original_label=7, adversarial_label=9, count=266
# attack success, original_label=6, adversarial_label=5, count=267
# attack success, original_label=6, adversarial_label=5, count=268
# attack success, original_label=2, adversarial_label=7, count=269
# attack success, original_label=1, adversarial_label=2, count=270
# attack success, original_label=7, adversarial_label=9, count=271
# attack success, original_label=5, adversarial_label=9, count=272
# attack success, original_label=1, adversarial_label=7, count=273
# attack success, original_label=4, adversarial_label=1, count=274
# attack success, original_label=2, adversarial_label=8, count=275
# attack success, original_label=9, adversarial_label=4, count=276
# attack success, original_label=5, adversarial_label=8, count=277
# attack success, original_label=9, adversarial_label=5, count=278
# attack success, original_label=5, adversarial_label=8, count=279
# attack success, original_label=8, adversarial_label=5, count=280
# attack success, original_label=6, adversarial_label=8, count=281
# attack success, original_label=5, adversarial_label=9, count=282
# attack success, original_label=3, adversarial_label=5, count=283
# attack success, original_label=0, adversarial_label=6, count=284
# attack success, original_label=6, adversarial_label=8, count=285
# attack success, original_label=9, adversarial_label=7, count=286
# attack success, original_label=4, adversarial_label=7, count=287
# orig_label=4 adv_label=7 decoded_label=7
# attack success, original_label=9, adversarial_label=4, count=288
# attack success, original_label=5, adversarial_label=8, count=289
# attack success, original_label=1, adversarial_label=4, count=290
# attack success, original_label=9, adversarial_label=4, count=291
# attack success, original_label=5, adversarial_label=9, count=292
# attack success, original_label=0, adversarial_label=6, count=293
# attack success, original_label=7, adversarial_label=9, count=294
# attack success, original_label=4, adversarial_label=8, count=295
# attack success, original_label=8, adversarial_label=9, count=296
# attack success, original_label=1, adversarial_label=4, count=297
# attack success, original_label=0, adversarial_label=5, count=298
# attack success, original_label=4, adversarial_label=9, count=299
# attack success, original_label=0, adversarial_label=6, count=300
# attack success, original_label=3, adversarial_label=9, count=301
# attack success, original_label=0, adversarial_label=6, count=302
# attack success, original_label=0, adversarial_label=6, count=303
# attack success, original_label=3, adversarial_label=5, count=304
# attack success, original_label=0, adversarial_label=6, count=305
# attack success, original_label=8, adversarial_label=9, count=306
# attack success, original_label=4, adversarial_label=9, count=307
# attack success, original_label=4, adversarial_label=9, count=308
# attack success, original_label=3, adversarial_label=9, count=309
# attack success, original_label=0, adversarial_label=4, count=310
# attack success, original_label=0, adversarial_label=6, count=311
# attack success, original_label=2, adversarial_label=1, count=312
# attack success, original_label=9, adversarial_label=4, count=313
# attack success, original_label=8, adversarial_label=5, count=314
# orig_label=8 adv_label=5 decoded_label=5
# attack success, original_label=4, adversarial_label=6, count=315
# attack success, original_label=1, adversarial_label=6, count=316
# attack success, original_label=6, adversarial_label=0, count=317
# attack success, original_label=8, adversarial_label=5, count=318
# orig_label=8 adv_label=5 decoded_label=5
# attack success, original_label=3, adversarial_label=5, count=319
# attack success, original_label=6, adversarial_label=0, count=320
# attack success, original_label=0, adversarial_label=6, count=321
# attack success, original_label=3, adversarial_label=8, count=322
# attack success, original_label=5, adversarial_label=9, count=323
# attack success, original_label=6, adversarial_label=5, count=324
# attack success, original_label=8, adversarial_label=5, count=325
# attack success, original_label=9, adversarial_label=4, count=326
# attack success, original_label=4, adversarial_label=9, count=327
# attack success, original_label=6, adversarial_label=0, count=328
# attack success, original_label=9, adversarial_label=4, count=329
# attack success, original_label=3, adversarial_label=9, count=330
# attack success, original_label=3, adversarial_label=1, count=331
# attack success, original_label=6, adversarial_label=5, count=332
# attack success, original_label=7, adversarial_label=9, count=333
# attack success, original_label=5, adversarial_label=8, count=334
# attack success, original_label=5, adversarial_label=8, count=335
# orig_label=5 adv_label=8 decoded_label=8
# attack success, original_label=3, adversarial_label=9, count=336
# attack success, original_label=6, adversarial_label=5, count=337
# attack success, original_label=1, adversarial_label=7, count=338
# attack success, original_label=7, adversarial_label=1, count=339
# attack success, original_label=5, adversarial_label=8, count=340
# attack success, original_label=2, adversarial_label=7, count=341
# attack success, original_label=7, adversarial_label=9, count=342
# attack success, original_label=1, adversarial_label=4, count=343
# attack success, original_label=0, adversarial_label=2, count=344
# attack success, original_label=7, adversarial_label=9, count=345
# attack success, original_label=5, adversarial_label=8, count=346
# attack success, original_label=8, adversarial_label=2, count=347
# attack success, original_label=7, adversarial_label=2, count=348
# attack success, original_label=7, adversarial_label=9, count=349
# attack success, original_label=2, adversarial_label=7, count=350
# attack success, original_label=1, adversarial_label=7, count=351
# attack success, original_label=3, adversarial_label=2, count=352
# attack success, original_label=4, adversarial_label=7, count=353
# attack success, original_label=6, adversarial_label=5, count=354
# attack success, original_label=1, adversarial_label=3, count=355
# attack success, original_label=1, adversarial_label=8, count=356
# attack success, original_label=2, adversarial_label=7, count=357
# attack success, original_label=7, adversarial_label=1, count=358
# attack success, original_label=5, adversarial_label=9, count=359
# attack success, original_label=5, adversarial_label=8, count=360
# attack success, original_label=5, adversarial_label=9, count=361
# attack success, original_label=2, adversarial_label=4, count=362
# attack success, original_label=0, adversarial_label=6, count=363
# attack success, original_label=3, adversarial_label=5, count=364
# attack success, original_label=1, adversarial_label=4, count=365
# attack success, original_label=4, adversarial_label=9, count=366
# attack success, original_label=5, adversarial_label=8, count=367
# attack success, original_label=3, adversarial_label=9, count=368
# attack success, original_label=1, adversarial_label=4, count=369
# attack success, original_label=6, adversarial_label=0, count=370
# attack success, original_label=6, adversarial_label=0, count=371
# attack success, original_label=6, adversarial_label=5, count=372
# attack success, original_label=4, adversarial_label=7, count=373
# attack success, original_label=2, adversarial_label=8, count=374
# attack success, original_label=4, adversarial_label=7, count=375
# attack success, original_label=4, adversarial_label=6, count=376
# attack success, original_label=1, adversarial_label=7, count=377
# attack success, original_label=1, adversarial_label=7, count=378
# attack success, original_label=2, adversarial_label=8, count=379
# attack success, original_label=5, adversarial_label=9, count=380
# attack success, original_label=7, adversarial_label=2, count=381
# attack success, original_label=7, adversarial_label=5, count=382
# attack success, original_label=8, adversarial_label=9, count=383
# attack success, original_label=1, adversarial_label=4, count=384
# attack success, original_label=6, adversarial_label=0, count=385
# attack success, original_label=1, adversarial_label=7, count=386
# attack success, original_label=1, adversarial_label=7, count=387
# attack success, original_label=4, adversarial_label=7, count=388
# attack success, original_label=0, adversarial_label=6, count=389
# attack success, original_label=2, adversarial_label=7, count=390
# attack success, original_label=5, adversarial_label=8, count=391
# attack success, original_label=3, adversarial_label=9, count=392
# attack success, original_label=2, adversarial_label=0, count=393
# attack success, original_label=4, adversarial_label=7, count=394
# attack success, original_label=3, adversarial_label=5, count=395
# attack success, original_label=1, adversarial_label=7, count=396
# attack success, original_label=7, adversarial_label=9, count=397
# attack success, original_label=8, adversarial_label=9, count=398
# attack success, original_label=3, adversarial_label=8, count=399
# attack success, original_label=7, adversarial_label=2, count=400
# attack success, original_label=2, adversarial_label=7, count=401
# attack success, original_label=5, adversarial_label=9, count=402
# attack success, original_label=5, adversarial_label=9, count=403
# attack success, original_label=7, adversarial_label=1, count=404
# orig_label=7 adv_label=1 decoded_label=1
# attack success, original_label=0, adversarial_label=6, count=405
# attack success, original_label=1, adversarial_label=4, count=406
# attack success, original_label=1, adversarial_label=6, count=407
# attack success, original_label=3, adversarial_label=8, count=408
# attack success, original_label=7, adversarial_label=9, count=409
# attack success, original_label=9, adversarial_label=4, count=410
# attack success, original_label=7, adversarial_label=9, count=411
# attack success, original_label=2, adversarial_label=0, count=412
# attack success, original_label=6, adversarial_label=5, count=413
# attack success, original_label=0, adversarial_label=8, count=414
# attack success, original_label=5, adversarial_label=9, count=415
# attack success, original_label=3, adversarial_label=9, count=416
# attack success, original_label=9, adversarial_label=4, count=417
# attack success, original_label=8, adversarial_label=2, count=418
# attack success, original_label=9, adversarial_label=4, count=419
# attack success, original_label=7, adversarial_label=1, count=420
# attack success, original_label=0, adversarial_label=2, count=421
# attack success, original_label=6, adversarial_label=5, count=422
# orig_label=6 adv_label=5 decoded_label=5
# attack success, original_label=9, adversarial_label=4, count=423
# attack success, original_label=8, adversarial_label=5, count=424
# attack success, original_label=8, adversarial_label=7, count=425
# attack success, original_label=8, adversarial_label=5, count=426
# attack success, original_label=1, adversarial_label=4, count=427
# attack success, original_label=7, adversarial_label=9, count=428
# attack success, original_label=1, adversarial_label=4, count=429
# attack success, original_label=2, adversarial_label=7, count=430
# attack success, original_label=0, adversarial_label=6, count=431
# attack success, original_label=7, adversarial_label=9, count=432
# attack success, original_label=6, adversarial_label=0, count=433
# attack success, original_label=8, adversarial_label=5, count=434
# attack success, original_label=6, adversarial_label=5, count=435
# attack success, original_label=3, adversarial_label=9, count=436
# attack success, original_label=2, adversarial_label=3, count=437
# attack success, original_label=7, adversarial_label=2, count=438
# attack success, original_label=9, adversarial_label=4, count=439
# attack success, original_label=4, adversarial_label=0, count=440
# attack success, original_label=6, adversarial_label=3, count=441
# attack success, original_label=6, adversarial_label=2, count=442
# attack success, original_label=7, adversarial_label=4, count=443
# attack success, original_label=7, adversarial_label=9, count=444
# attack success, original_label=2, adversarial_label=7, count=445
# attack success, original_label=6, adversarial_label=5, count=446
# attack success, original_label=0, adversarial_label=4, count=447
# attack success, original_label=1, adversarial_label=4, count=448
# attack success, original_label=4, adversarial_label=8, count=449
# attack success, original_label=5, adversarial_label=3, count=450
# attack success, original_label=6, adversarial_label=5, count=451
# attack success, original_label=8, adversarial_label=5, count=452
# attack success, original_label=8, adversarial_label=3, count=453
# attack success, original_label=3, adversarial_label=5, count=454
# attack success, original_label=0, adversarial_label=6, count=455
# attack success, original_label=5, adversarial_label=8, count=456
# attack success, original_label=8, adversarial_label=5, count=457
# attack success, original_label=2, adversarial_label=7, count=458
# attack success, original_label=1, adversarial_label=7, count=459
# attack success, original_label=7, adversarial_label=9, count=460
# attack success, original_label=2, adversarial_label=7, count=461
# attack success, original_label=2, adversarial_label=7, count=462
# attack success, original_label=7, adversarial_label=0, count=463
# attack success, original_label=3, adversarial_label=5, count=464
# orig_label=3 adv_label=5 decoded_label=5
# attack success, original_label=4, adversarial_label=7, count=465
# attack success, original_label=5, adversarial_label=3, count=466
# attack success, original_label=5, adversarial_label=8, count=467
# attack success, original_label=3, adversarial_label=5, count=468
# attack success, original_label=0, adversarial_label=4, count=469
# attack success, original_label=8, adversarial_label=9, count=470
# attack success, original_label=3, adversarial_label=9, count=471
# attack success, original_label=4, adversarial_label=9, count=472
# attack success, original_label=3, adversarial_label=5, count=473
# attack success, original_label=7, adversarial_label=9, count=474
# attack success, original_label=4, adversarial_label=9, count=475
# attack success, original_label=0, adversarial_label=9, count=476
# attack success, original_label=1, adversarial_label=7, count=477
# attack success, original_label=2, adversarial_label=8, count=478
# attack success, original_label=9, adversarial_label=4, count=479
# attack success, original_label=7, adversarial_label=9, count=480
# attack success, original_label=7, adversarial_label=2, count=481
# attack success, original_label=4, adversarial_label=7, count=482
# attack success, original_label=8, adversarial_label=5, count=483
# attack success, original_label=4, adversarial_label=9, count=484
# attack success, original_label=4, adversarial_label=8, count=485
# orig_label=4 adv_label=8 decoded_label=8
# attack success, original_label=6, adversarial_label=5, count=486
# attack success, original_label=9, adversarial_label=7, count=487
# attack success, original_label=1, adversarial_label=2, count=488
# attack success, original_label=0, adversarial_label=2, count=489
# attack success, original_label=9, adversarial_label=4, count=490
# attack success, original_label=1, adversarial_label=7, count=491
# attack success, original_label=8, adversarial_label=2, count=492
# attack success, original_label=0, adversarial_label=9, count=493
# attack success, original_label=8, adversarial_label=5, count=494
# attack success, original_label=1, adversarial_label=4, count=495
# attack success, original_label=6, adversarial_label=0, count=496
# attack success, original_label=4, adversarial_label=9, count=497
# attack success, original_label=6, adversarial_label=5, count=498
# attack success, original_label=3, adversarial_label=5, count=499
# attack success, original_label=6, adversarial_label=5, count=500
# attack success, original_label=6, adversarial_label=5, count=501
# attack success, original_label=4, adversarial_label=9, count=502
# attack success, original_label=8, adversarial_label=7, count=503
# attack success, original_label=4, adversarial_label=9, count=504
# attack success, original_label=1, adversarial_label=4, count=505
# attack success, original_label=1, adversarial_label=7, count=506
# attack success, original_label=1, adversarial_label=4, count=507
# attack success, original_label=3, adversarial_label=9, count=508
# attack success, original_label=7, adversarial_label=4, count=509
# attack success, original_label=4, adversarial_label=9, count=510
# orig_label=4 adv_label=9 decoded_label=9
# attack success, original_label=6, adversarial_label=0, count=511
# attack success, original_label=6, adversarial_label=5, count=512
# attack success, original_label=0, adversarial_label=6, count=513
# attack success, original_label=1, adversarial_label=7, count=514
# attack success, original_label=1, adversarial_label=4, count=515
# attack success, original_label=1, adversarial_label=4, count=516
# attack success, original_label=3, adversarial_label=7, count=517
# attack success, original_label=2, adversarial_label=7, count=518
# attack success, original_label=6, adversarial_label=3, count=519
# attack success, original_label=4, adversarial_label=8, count=520
# attack success, original_label=7, adversarial_label=3, count=521
# attack success, original_label=3, adversarial_label=9, count=522
# attack success, original_label=5, adversarial_label=3, count=523
# attack success, original_label=2, adversarial_label=4, count=524
# attack success, original_label=5, adversarial_label=8, count=525
# attack success, original_label=1, adversarial_label=4, count=526
# attack success, original_label=9, adversarial_label=4, count=527
# attack success, original_label=4, adversarial_label=9, count=528
# attack success, original_label=3, adversarial_label=9, count=529
# attack success, original_label=6, adversarial_label=5, count=530
# attack success, original_label=2, adversarial_label=8, count=531
# attack success, original_label=1, adversarial_label=4, count=532
# attack success, original_label=0, adversarial_label=6, count=533
# attack success, original_label=5, adversarial_label=8, count=534
# attack success, original_label=4, adversarial_label=9, count=535
# attack success, original_label=3, adversarial_label=8, count=536
# orig_label=3 adv_label=8 decoded_label=8
# attack success, original_label=2, adversarial_label=1, count=537
# attack success, original_label=2, adversarial_label=7, count=538
# attack success, original_label=9, adversarial_label=4, count=539
# attack success, original_label=6, adversarial_label=0, count=540
# attack success, original_label=3, adversarial_label=9, count=541
# attack success, original_label=1, adversarial_label=4, count=542
# attack success, original_label=7, adversarial_label=9, count=543
# attack success, original_label=7, adversarial_label=3, count=544
# attack success, original_label=8, adversarial_label=7, count=545
# attack success, original_label=5, adversarial_label=8, count=546
# attack success, original_label=4, adversarial_label=2, count=547
# attack success, original_label=4, adversarial_label=8, count=548
# attack success, original_label=3, adversarial_label=5, count=549
# attack success, original_label=9, adversarial_label=8, count=550
# attack success, original_label=7, adversarial_label=2, count=551
# attack success, original_label=4, adversarial_label=9, count=552
# attack success, original_label=7, adversarial_label=2, count=553
# attack success, original_label=8, adversarial_label=9, count=554
# attack success, original_label=8, adversarial_label=5, count=555
# attack success, original_label=4, adversarial_label=7, count=556
# attack success, original_label=0, adversarial_label=7, count=557
# attack success, original_label=4, adversarial_label=9, count=558
# attack success, original_label=8, adversarial_label=9, count=559
# attack success, original_label=6, adversarial_label=8, count=560
# attack success, original_label=6, adversarial_label=5, count=561
# attack success, original_label=3, adversarial_label=7, count=562
# attack success, original_label=9, adversarial_label=8, count=563
# attack success, original_label=7, adversarial_label=9, count=564
# attack success, original_label=9, adversarial_label=4, count=565
# attack success, original_label=3, adversarial_label=5, count=566
# orig_label=3 adv_label=5 decoded_label=5
# attack success, original_label=4, adversarial_label=8, count=567
# attack success, original_label=3, adversarial_label=5, count=568
# attack success, original_label=0, adversarial_label=9, count=569
# attack success, original_label=5, adversarial_label=9, count=570
# attack success, original_label=6, adversarial_label=4, count=571
# attack success, original_label=1, adversarial_label=4, count=572
# attack success, original_label=2, adversarial_label=7, count=573
# attack success, original_label=5, adversarial_label=8, count=574
# attack success, original_label=1, adversarial_label=4, count=575
# attack success, original_label=0, adversarial_label=2, count=576
# attack success, original_label=8, adversarial_label=9, count=577
# attack success, original_label=3, adversarial_label=5, count=578
# attack success, original_label=0, adversarial_label=2, count=579
# attack success, original_label=9, adversarial_label=4, count=580
# attack success, original_label=1, adversarial_label=8, count=581
# attack success, original_label=7, adversarial_label=9, count=582
# attack success, original_label=8, adversarial_label=9, count=583
# attack success, original_label=0, adversarial_label=6, count=584
# attack success, original_label=6, adversarial_label=0, count=585
# attack success, original_label=9, adversarial_label=4, count=586
# attack success, original_label=1, adversarial_label=9, count=587
# attack success, original_label=2, adversarial_label=7, count=588
# attack success, original_label=1, adversarial_label=4, count=589
# attack success, original_label=8, adversarial_label=5, count=590
# attack success, original_label=4, adversarial_label=7, count=591
# attack success, original_label=3, adversarial_label=5, count=592
# attack success, original_label=2, adversarial_label=7, count=593
# attack success, original_label=7, adversarial_label=2, count=594
# attack success, original_label=6, adversarial_label=0, count=595
# attack success, original_label=8, adversarial_label=3, count=596
# attack success, original_label=6, adversarial_label=8, count=597
# attack success, original_label=1, adversarial_label=4, count=598
# attack success, original_label=7, adversarial_label=4, count=599
# attack success, original_label=2, adversarial_label=7, count=600
# attack success, original_label=0, adversarial_label=9, count=601
# attack success, original_label=2, adversarial_label=7, count=602
# attack success, original_label=3, adversarial_label=7, count=603
# attack success, original_label=0, adversarial_label=1, count=604
# attack success, original_label=4, adversarial_label=7, count=605
# attack success, original_label=6, adversarial_label=5, count=606
# attack success, original_label=3, adversarial_label=5, count=607
# attack success, original_label=9, adversarial_label=4, count=608
# attack success, original_label=4, adversarial_label=9, count=609
# attack success, original_label=8, adversarial_label=3, count=610
# attack success, original_label=8, adversarial_label=0, count=611
# attack success, original_label=0, adversarial_label=5, count=612
# attack success, original_label=9, adversarial_label=5, count=613
# orig_label=9 adv_label=5 decoded_label=5
# attack success, original_label=1, adversarial_label=7, count=614
# attack success, original_label=7, adversarial_label=1, count=615
# attack success, original_label=2, adversarial_label=7, count=616
# attack success, original_label=4, adversarial_label=9, count=617
# attack success, original_label=7, adversarial_label=9, count=618
# attack success, original_label=1, adversarial_label=8, count=619
# attack success, original_label=9, adversarial_label=4, count=620
# attack success, original_label=6, adversarial_label=5, count=621
# attack success, original_label=2, adversarial_label=7, count=622
# attack success, original_label=3, adversarial_label=5, count=623
# attack success, original_label=6, adversarial_label=5, count=624
# attack success, original_label=4, adversarial_label=8, count=625
# attack success, original_label=1, adversarial_label=4, count=626
# attack success, original_label=8, adversarial_label=9, count=627
# attack success, original_label=5, adversarial_label=8, count=628
# attack success, original_label=9, adversarial_label=4, count=629
# attack success, original_label=5, adversarial_label=8, count=630
# attack success, original_label=5, adversarial_label=8, count=631
# attack success, original_label=1, adversarial_label=7, count=632
# attack success, original_label=1, adversarial_label=4, count=633
# attack success, original_label=0, adversarial_label=1, count=634
# orig_label=0 adv_label=1 decoded_label=1
# attack success, original_label=3, adversarial_label=8, count=635
# attack success, original_label=0, adversarial_label=6, count=636
# attack success, original_label=8, adversarial_label=9, count=637
# attack success, original_label=0, adversarial_label=9, count=638
# attack success, original_label=6, adversarial_label=0, count=639
# attack success, original_label=4, adversarial_label=9, count=640
# attack success, original_label=2, adversarial_label=7, count=641
# attack success, original_label=6, adversarial_label=5, count=642
# attack success, original_label=9, adversarial_label=4, count=643
# attack success, original_label=3, adversarial_label=5, count=644
# attack success, original_label=9, adversarial_label=4, count=645
# attack success, original_label=1, adversarial_label=8, count=646
# attack success, original_label=8, adversarial_label=9, count=647
# attack success, original_label=3, adversarial_label=9, count=648
# attack success, original_label=4, adversarial_label=2, count=649
# attack success, original_label=5, adversarial_label=9, count=650
# attack success, original_label=9, adversarial_label=4, count=651
# attack success, original_label=4, adversarial_label=8, count=652
# attack success, original_label=7, adversarial_label=9, count=653
# attack success, original_label=4, adversarial_label=9, count=654
# attack success, original_label=5, adversarial_label=8, count=655
# attack success, original_label=6, adversarial_label=5, count=656
# attack success, original_label=8, adversarial_label=4, count=657
# attack success, original_label=7, adversarial_label=2, count=658
# attack success, original_label=3, adversarial_label=5, count=659
# attack success, original_label=2, adversarial_label=4, count=660
# attack success, original_label=9, adversarial_label=4, count=661
# attack success, original_label=5, adversarial_label=8, count=662
# attack success, original_label=0, adversarial_label=9, count=663
# attack success, original_label=5, adversarial_label=8, count=664
# attack success, original_label=1, adversarial_label=4, count=665
# attack success, original_label=3, adversarial_label=8, count=666
# attack success, original_label=6, adversarial_label=5, count=667
# attack success, original_label=1, adversarial_label=4, count=668
# attack success, original_label=2, adversarial_label=7, count=669
# attack success, original_label=9, adversarial_label=4, count=670
# attack success, original_label=8, adversarial_label=5, count=671
# attack success, original_label=6, adversarial_label=5, count=672
# attack success, original_label=5, adversarial_label=9, count=673
# attack success, original_label=4, adversarial_label=7, count=674
# attack success, original_label=7, adversarial_label=9, count=675
# attack success, original_label=1, adversarial_label=4, count=676
# attack success, original_label=1, adversarial_label=4, count=677
# attack success, original_label=6, adversarial_label=5, count=678
# attack success, original_label=5, adversarial_label=9, count=679
# attack success, original_label=5, adversarial_label=8, count=680
# attack success, original_label=6, adversarial_label=5, count=681
# attack success, original_label=8, adversarial_label=5, count=682
# attack success, original_label=2, adversarial_label=7, count=683
# attack success, original_label=5, adversarial_label=8, count=684
# attack success, original_label=7, adversarial_label=1, count=685
# attack success, original_label=2, adversarial_label=8, count=686
# attack success, original_label=4, adversarial_label=9, count=687
# attack success, original_label=5, adversarial_label=9, count=688
# attack success, original_label=4, adversarial_label=8, count=689
# attack success, original_label=1, adversarial_label=7, count=690
# attack success, original_label=3, adversarial_label=5, count=691
# attack success, original_label=8, adversarial_label=9, count=692
# attack success, original_label=7, adversarial_label=1, count=693
# attack success, original_label=9, adversarial_label=4, count=694
# attack success, original_label=2, adversarial_label=7, count=695
# attack success, original_label=3, adversarial_label=5, count=696
# attack success, original_label=1, adversarial_label=4, count=697
# attack success, original_label=4, adversarial_label=9, count=698
# attack success, original_label=8, adversarial_label=0, count=699
# attack success, original_label=6, adversarial_label=0, count=700
# attack success, original_label=7, adversarial_label=9, count=701
# attack success, original_label=3, adversarial_label=8, count=702
# attack success, original_label=8, adversarial_label=5, count=703
# attack success, original_label=9, adversarial_label=4, count=704
# attack success, original_label=4, adversarial_label=7, count=705
# attack success, original_label=9, adversarial_label=4, count=706
# attack success, original_label=8, adversarial_label=5, count=707
# attack success, original_label=3, adversarial_label=5, count=708
# attack success, original_label=1, adversarial_label=4, count=709
# attack success, original_label=7, adversarial_label=9, count=710
# attack success, original_label=2, adversarial_label=7, count=711
# attack success, original_label=8, adversarial_label=5, count=712
# attack success, original_label=5, adversarial_label=9, count=713
# attack success, original_label=9, adversarial_label=8, count=714
# attack success, original_label=5, adversarial_label=8, count=715
# attack success, original_label=5, adversarial_label=3, count=716
# attack success, original_label=4, adversarial_label=9, count=717
# attack success, original_label=7, adversarial_label=9, count=718
# attack success, original_label=5, adversarial_label=3, count=719
# attack success, original_label=2, adversarial_label=7, count=720
# attack success, original_label=8, adversarial_label=9, count=721
# attack success, original_label=2, adversarial_label=1, count=722
# attack success, original_label=2, adversarial_label=7, count=723
# attack success, original_label=0, adversarial_label=2, count=724
# ...
# attack success, original_label=4, adversarial_label=7, count=765
# attack success, original_label=2, adversarial_label=3, count=766
# attack success, original_label=1, adversarial_label=4, count=767
# attack success, original_label=0, adversarial_label=5, count=768
# attack success, original_label=2, adversarial_label=1, count=769
# attack success, original_label=1, adversarial_label=4, count=770
# attack success, original_label=6, adversarial_label=8, count=771
# attack success, original_label=0, adversarial_label=6, count=772
# attack success, original_label=9, adversarial_label=4, count=773
# attack success, original_label=7, adversarial_label=2, count=774
# attack success, original_label=9, adversarial_label=5, count=775
# attack success, original_label=2, adversarial_label=7, count=776
# attack success, original_label=4, adversarial_label=7, count=777
# attack success, original_label=3, adversarial_label=5, count=778
# attack success, original_label=9, adversarial_label=4, count=779
# attack success, original_label=0, adversarial_label=9, count=780
# attack success, original_label=7, adversarial_label=9, count=781
# attack success, original_label=1, adversarial_label=4, count=782
# attack success, original_label=6, adversarial_label=5, count=783
# attack success, original_label=3, adversarial_label=5, count=784
# attack success, original_label=7, adversarial_label=2, count=785
# attack success, original_label=2, adversarial_label=7, count=786
# attack success, original_label=1, adversarial_label=8, count=787
# attack success, original_label=0, adversarial_label=6, count=788
# attack success, original_label=4, adversarial_label=7, count=789
# attack success, original_label=9, adversarial_label=4, count=790
# attack success, original_label=4, adversarial_label=7, count=791
# attack success, original_label=3, adversarial_label=5, count=792
# orig_label=3 adv_label=5 decoded_label=5
# attack success, original_label=6, adversarial_label=0, count=793
# attack success, original_label=6, adversarial_label=5, count=794
# attack success, original_label=4, adversarial_label=9, count=795
# orig_label=4 adv_label=9 decoded_label=9
# attack success, original_label=1, adversarial_label=4, count=796
# attack success, original_label=9, adversarial_label=4, count=797
# attack success, original_label=8, adversarial_label=3, count=798
# attack success, original_label=2, adversarial_label=7, count=799
# attack success, original_label=1, adversarial_label=4, count=800
# attack success, original_label=0, adversarial_label=8, count=801
# attack success, original_label=8, adversarial_label=5, count=802
# attack success, original_label=2, adversarial_label=7, count=803
# attack success, original_label=8, adversarial_label=9, count=804
# attack success, original_label=5, adversarial_label=9, count=805
# attack success, original_label=1, adversarial_label=0, count=806
# attack success, original_label=9, adversarial_label=4, count=807
# attack success, original_label=6, adversarial_label=5, count=808
# attack success, original_label=3, adversarial_label=9, count=809
# attack success, original_label=3, adversarial_label=9, count=810
# attack success, original_label=2, adversarial_label=7, count=811
# attack success, original_label=0, adversarial_label=2, count=812
# attack success, original_label=8, adversarial_label=5, count=813
# attack success, original_label=5, adversarial_label=8, count=814
# attack success, original_label=4, adversarial_label=7, count=815
# attack success, original_label=7, adversarial_label=4, count=816
# attack success, original_label=5, adversarial_label=9, count=817
# attack success, original_label=7, adversarial_label=9, count=818
# attack success, original_label=6, adversarial_label=5, count=819
# attack success, original_label=3, adversarial_label=9, count=820
# attack success, original_label=9, adversarial_label=4, count=821
# attack success, original_label=2, adversarial_label=7, count=822
# orig_label=2 adv_label=7 decoded_label=7
# attack success, original_label=3, adversarial_label=8, count=823
# attack success, original_label=1, adversarial_label=4, count=824
# attack success, original_label=4, adversarial_label=9, count=825
# attack success, original_label=3, adversarial_label=2, count=826
# attack success, original_label=8, adversarial_label=7, count=827
# attack success, original_label=1, adversarial_label=8, count=828
# attack success, original_label=9, adversarial_label=4, count=829
# attack success, original_label=0, adversarial_label=2, count=830
# attack success, original_label=1, adversarial_label=4, count=831
# attack success, original_label=9, adversarial_label=4, count=832
# attack success, original_label=8, adversarial_label=2, count=833
# attack success, original_label=4, adversarial_label=9, count=834
# attack success, original_label=6, adversarial_label=5, count=835
# attack success, original_label=6, adversarial_label=0, count=836
# attack success, original_label=4, adversarial_label=9, count=837
# attack success, original_label=7, adversarial_label=9, count=838
# orig_label=7 adv_label=9 decoded_label=9
# attack success, original_label=5, adversarial_label=3, count=839
# attack success, original_label=0, adversarial_label=6, count=840
# attack success, original_label=0, adversarial_label=6, count=841
# attack success, original_label=2, adversarial_label=3, count=842
# attack success, original_label=8, adversarial_label=2, count=843
# attack success, original_label=2, adversarial_label=7, count=844
# attack success, original_label=0, adversarial_label=4, count=845
# attack success, original_label=8, adversarial_label=5, count=846
# attack success, original_label=2, adversarial_label=4, count=847
# attack success, original_label=4, adversarial_label=7, count=848
# attack success, original_label=5, adversarial_label=8, count=849
# attack success, original_label=2, adversarial_label=0, count=850
# attack success, original_label=0, adversarial_label=9, count=851
# attack success, original_label=0, adversarial_label=5, count=852
# attack success, original_label=3, adversarial_label=5, count=853
# attack success, original_label=7, adversarial_label=9, count=854
# attack success, original_label=7, adversarial_label=1, count=855
# attack success, original_label=2, adversarial_label=7, count=856
# attack success, original_label=8, adversarial_label=5, count=857
# attack success, original_label=5, adversarial_label=9, count=858
# attack success, original_label=1, adversarial_label=4, count=859
# attack success, original_label=2, adversarial_label=8, count=860
# attack success, original_label=2, adversarial_label=7, count=861
# attack success, original_label=6, adversarial_label=8, count=862
# attack success, original_label=4, adversarial_label=2, count=863
# attack success, original_label=6, adversarial_label=5, count=864
# attack success, original_label=6, adversarial_label=5, count=865
# attack success, original_label=6, adversarial_label=5, count=866
# attack success, original_label=3, adversarial_label=9, count=867
# attack success, original_label=8, adversarial_label=0, count=868
# orig_label=8 adv_label=0 decoded_label=0
# attack success, original_label=5, adversarial_label=8, count=869
# attack success, original_label=1, adversarial_label=4, count=870
# attack success, original_label=8, adversarial_label=2, count=871
# attack success, original_label=6, adversarial_label=5, count=872
# orig_label=6 adv_label=5 decoded_label=5
# attack success, original_label=5, adversarial_label=3, count=873
# attack success, original_label=3, adversarial_label=8, count=874
# attack success, original_label=3, adversarial_label=0, count=875
# attack success, original_label=0, adversarial_label=9, count=876
# attack success, original_label=7, adversarial_label=9, count=877
# attack success, original_label=7, adversarial_label=9, count=878
# attack success, original_label=0, adversarial_label=5, count=879
# attack success, original_label=9, adversarial_label=4, count=880
# orig_label=9 adv_label=4 decoded_label=4
# attack success, original_label=0, adversarial_label=9, count=881
# attack success, original_label=9, adversarial_label=8, count=882
# attack success, original_label=0, adversarial_label=6, count=883
# attack success, original_label=7, adversarial_label=5, count=884
# attack success, original_label=8, adversarial_label=0, count=885
# attack success, original_label=1, adversarial_label=4, count=886
# attack success, original_label=3, adversarial_label=8, count=887
# attack success, original_label=9, adversarial_label=4, count=888
# attack success, original_label=1, adversarial_label=4, count=889
# attack success, original_label=9, adversarial_label=4, count=890
# attack success, original_label=6, adversarial_label=5, count=891
# attack success, original_label=7, adversarial_label=9, count=892
# attack success, original_label=9, adversarial_label=4, count=893
# attack success, original_label=5, adversarial_label=3, count=894
# attack success, original_label=1, adversarial_label=8, count=895
# attack success, original_label=6, adversarial_label=5, count=896
# attack success, original_label=2, adversarial_label=8, count=897
# attack success, original_label=8, adversarial_label=0, count=898
# attack success, original_label=2, adversarial_label=1, count=899
# attack success, original_label=4, adversarial_label=9, count=900
# attack success, original_label=2, adversarial_label=3, count=901
# attack success, original_label=8, adversarial_label=5, count=902
# orig_label=8 adv_label=5 decoded_label=5
# attack success, original_label=6, adversarial_label=0, count=903
# attack success, original_label=2, adversarial_label=8, count=904
# attack success, original_label=1, adversarial_label=4, count=905
# attack success, original_label=6, adversarial_label=5, count=906
# attack success, original_label=2, adversarial_label=0, count=907
# attack success, original_label=0, adversarial_label=4, count=908
# attack success, original_label=2, adversarial_label=7, count=909
# attack success, original_label=3, adversarial_label=5, count=910
# attack success, original_label=9, adversarial_label=4, count=911
# attack success, original_label=8, adversarial_label=3, count=912
# orig_label=8 adv_label=3 decoded_label=3
# attack success, original_label=4, adversarial_label=7, count=913
# attack success, original_label=9, adversarial_label=4, count=914
# attack success, original_label=5, adversarial_label=9, count=915
# attack success, original_label=8, adversarial_label=9, count=916
# attack success, original_label=4, adversarial_label=9, count=917
# attack success, original_label=7, adversarial_label=9, count=918
# attack success, original_label=4, adversarial_label=9, count=919
# attack success, original_label=5, adversarial_label=9, count=920
# attack success, original_label=2, adversarial_label=0, count=921
# attack success, original_label=2, adversarial_label=7, count=922
# attack success, original_label=1, adversarial_label=4, count=923
# attack success, original_label=3, adversarial_label=7, count=924
# attack success, original_label=1, adversarial_label=8, count=925
# attack success, original_label=3, adversarial_label=2, count=926
# orig_label=3 adv_label=2 decoded_label=2
# attack success, original_label=1, adversarial_label=4, count=927
# attack success, original_label=4, adversarial_label=2, count=928
# attack success, original_label=1, adversarial_label=4, count=929
# attack success, original_label=1, adversarial_label=8, count=930
# attack success, original_label=8, adversarial_label=3, count=931
# attack success, original_label=8, adversarial_label=3, count=932
# attack success, original_label=3, adversarial_label=9, count=933
# attack success, original_label=5, adversarial_label=8, count=934
# attack success, original_label=6, adversarial_label=5, count=935
# attack success, original_label=2, adversarial_label=7, count=936
# attack success, original_label=0, adversarial_label=6, count=937
# attack success, original_label=4, adversarial_label=7, count=938
# attack success, original_label=9, adversarial_label=4, count=939
# attack success, original_label=8, adversarial_label=5, count=940
# attack success, original_label=9, adversarial_label=2, count=941
# attack success, original_label=9, adversarial_label=4, count=942
# attack success, original_label=7, adversarial_label=1, count=943
# attack success, original_label=4, adversarial_label=2, count=944
# attack success, original_label=4, adversarial_label=9, count=945
# attack success, original_label=8, adversarial_label=5, count=946
# attack success, original_label=0, adversarial_label=5, count=947
# attack success, original_label=8, adversarial_label=5, count=948
# attack success, original_label=4, adversarial_label=9, count=949
# attack success, original_label=7, adversarial_label=9, count=950
# attack success, original_label=4, adversarial_label=9, count=951
# attack success, original_label=2, adversarial_label=6, count=952
# attack success, original_label=4, adversarial_label=8, count=953
# attack success, original_label=4, adversarial_label=9, count=954
# attack success, original_label=7, adversarial_label=9, count=955
# attack success, original_label=2, adversarial_label=8, count=956
# attack success, original_label=9, adversarial_label=8, count=957
# attack success, original_label=6, adversarial_label=5, count=958
# attack success, original_label=5, adversarial_label=8, count=959
# attack success, original_label=2, adversarial_label=7, count=960
# attack success, original_label=0, adversarial_label=6, count=961
# attack success, original_label=6, adversarial_label=0, count=962
# attack success, original_label=3, adversarial_label=5, count=963
# attack success, original_label=9, adversarial_label=4, count=964
# attack success, original_label=8, adversarial_label=5, count=965
# attack success, original_label=0, adversarial_label=6, count=966
# attack success, original_label=5, adversarial_label=3, count=967
# attack success, original_label=3, adversarial_label=5, count=968
# attack success, original_label=2, adversarial_label=8, count=969
# attack success, original_label=8, adversarial_label=5, count=970
# attack success, original_label=4, adversarial_label=7, count=971
# attack success, original_label=0, adversarial_label=7, count=972
# attack success, original_label=4, adversarial_label=7, count=973
# attack success, original_label=9, adversarial_label=4, count=974
# attack success, original_label=8, adversarial_label=5, count=975
# attack success, original_label=1, adversarial_label=4, count=976
# attack success, original_label=1, adversarial_label=4, count=977
# attack success, original_label=2, adversarial_label=7, count=978
# attack success, original_label=4, adversarial_label=9, count=979
# attack success, original_label=7, adversarial_label=9, count=980
# attack success, original_label=1, adversarial_label=7, count=981
# attack success, original_label=8, adversarial_label=5, count=982
# attack success, original_label=5, adversarial_label=9, count=983
# attack success, original_label=1, adversarial_label=4, count=984
# attack success, original_label=1, adversarial_label=2, count=985
# attack success, original_label=5, adversarial_label=8, count=986
# orig_label=5 adv_label=8 decoded_label=8
# attack success, original_label=1, adversarial_label=4, count=987
# attack success, original_label=0, adversarial_label=5, count=988
# attack success, original_label=3, adversarial_label=5, count=989
# attack success, original_label=7, adversarial_label=9, count=990
# attack success, original_label=5, adversarial_label=8, count=991
# attack success, original_label=1, adversarial_label=4, count=992
# attack success, original_label=4, adversarial_label=7, count=993
# attack success, original_label=5, adversarial_label=9, count=994
# attack success, original_label=6, adversarial_label=5, count=995
# attack success, original_label=8, adversarial_label=3, count=996
# attack success, original_label=3, adversarial_label=9, count=997
# attack success, original_label=9, adversarial_label=4, count=998
# attack success, original_label=0, adversarial_label=6, count=999
# attack success, original_label=5, adversarial_label=8, count=1000
# [TEST_DATASET]: fooling_count=1000, total_count=1000, fooling_rate=1.000000 decoded_fooling_count=37  decoded_fooling_count_rate=0.037000
# fgsm attack done
